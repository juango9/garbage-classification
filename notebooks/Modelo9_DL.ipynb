# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# /

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os
from tensorflow.keras.applications.densenet import preprocess_input

# %%
import random
import tensorflow as tf
import os

# Establecer semilla para reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1134  data/Garbage-classification/Garbage-classifica...    metal
# 2487  data/Garbage-classification/Garbage-classifica...    trash
# 2228  data/Garbage-classification/Garbage-classifica...  plastic
# 2346  data/Garbage-classification/Garbage-classifica...  plastic
# 2048  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print(f"📦 Dataset descargado en: {path}")
# Out:
# Downloading to /root/.cache/kagglehub/datasets/asdasdasasdas/garbage-classification/2.archive...
# 100%|██████████| 82.0M/82.0M [00:07<00:00, 11.0MB/s]
# Extracting files...
# 📦 Dataset descargado en: /root/.cache/kagglehub/datasets/asdasdasasdas/garbage-classification/versions/2

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual)

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []

    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']

        img = cv2.imread(ruta)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (size, size))
        #img = img.astype('float32') / 255.0

        images.append(img)
        labels.append(label)

    X = np.array(images)
    y = np.array(labels)

    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
x_train = preprocess_input(x_train.astype("float32"))
x_val = preprocess_input(x_val.astype("float32"))
x_test = preprocess_input(x_test.astype("float32"))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from modelo9 import estructura_modelo
from modelo_simple import compilar
from curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_),use_augmentation=True)
modelo
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_1               │ (None, 128, 128, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom_1 (RandomZoom)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_1               │ (None, 128, 128, 3)    │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_brightness_1             │ (None, 128, 128, 3)    │             0 │
# │ (RandomBrightness)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 4, 4, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,349,574 (28.04 MB)
#  Trainable params: 7,265,926 (27.72 MB)
#  Non-trainable params: 83,648 (326.75 KB)
# <Sequential name=sequential_2, built=True>

# %%
modelo=compilar(modelo,learning_rate=1e-4)

# %%
ReduceLROnPlateau=tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1
    )
EarlyStopping=tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        )

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=256,epochs=150,callbacks=[ReduceLROnPlateau,EarlyStopping])
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - loss: 2.4962 - sparse_categorical_accuracy: 0.2009 - val_loss: 1.8804 - val_sparse_categorical_accuracy: 0.2213 - learning_rate: 1.0000e-04
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.9310 - sparse_categorical_accuracy: 0.2370 - val_loss: 1.6040 - val_sparse_categorical_accuracy: 0.3755 - learning_rate: 1.0000e-04
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.7054 - sparse_categorical_accuracy: 0.2964 - val_loss: 1.4739 - val_sparse_categorical_accuracy: 0.4190 - learning_rate: 1.0000e-04
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.5655 - sparse_categorical_accuracy: 0.3691 - val_loss: 1.3920 - val_sparse_categorical_accuracy: 0.4466 - learning_rate: 1.0000e-04
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.4646 - sparse_categorical_accuracy: 0.4146 - val_loss: 1.3476 - val_sparse_categorical_accuracy: 0.4743 - learning_rate: 1.0000e-04
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - loss: 1.3844 - sparse_categorical_accuracy: 0.4443 - val_loss: 1.3208 - val_sparse_categorical_accuracy: 0.4941 - learning_rate: 1.0000e-04
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.3151 - sparse_categorical_accuracy: 0.4681 - val_loss: 1.2976 - val_sparse_categorical_accuracy: 0.5296 - learning_rate: 1.0000e-04
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.2380 - sparse_categorical_accuracy: 0.5260 - val_loss: 1.2643 - val_sparse_categorical_accuracy: 0.5217 - learning_rate: 1.0000e-04
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.1736 - sparse_categorical_accuracy: 0.5591 - val_loss: 1.2184 - val_sparse_categorical_accuracy: 0.5494 - learning_rate: 1.0000e-04
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 1.0824 - sparse_categorical_accuracy: 0.5893 - val_loss: 1.1045 - val_sparse_categorical_accuracy: 0.5968 - learning_rate: 1.0000e-04
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.9975 - sparse_categorical_accuracy: 0.6418 - val_loss: 1.0040 - val_sparse_categorical_accuracy: 0.6206 - learning_rate: 1.0000e-04
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.9291 - sparse_categorical_accuracy: 0.6606 - val_loss: 0.9679 - val_sparse_categorical_accuracy: 0.6601 - learning_rate: 1.0000e-04
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.8429 - sparse_categorical_accuracy: 0.6932 - val_loss: 0.9483 - val_sparse_categorical_accuracy: 0.6601 - learning_rate: 1.0000e-04
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.7941 - sparse_categorical_accuracy: 0.7165 - val_loss: 0.9291 - val_sparse_categorical_accuracy: 0.6917 - learning_rate: 1.0000e-04
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.7348 - sparse_categorical_accuracy: 0.7323 - val_loss: 0.8794 - val_sparse_categorical_accuracy: 0.7194 - learning_rate: 1.0000e-04
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.6836 - sparse_categorical_accuracy: 0.7521 - val_loss: 0.8310 - val_sparse_categorical_accuracy: 0.7312 - learning_rate: 1.0000e-04
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.6224 - sparse_categorical_accuracy: 0.7902 - val_loss: 0.8237 - val_sparse_categorical_accuracy: 0.7431 - learning_rate: 1.0000e-04
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.5594 - sparse_categorical_accuracy: 0.8075 - val_loss: 0.7782 - val_sparse_categorical_accuracy: 0.7312 - learning_rate: 1.0000e-04
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.5131 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.7531 - val_sparse_categorical_accuracy: 0.7470 - learning_rate: 1.0000e-04
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.4786 - sparse_categorical_accuracy: 0.8342 - val_loss: 0.8634 - val_sparse_categorical_accuracy: 0.7312 - learning_rate: 1.0000e-04
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.3983 - sparse_categorical_accuracy: 0.8629 - val_loss: 0.7775 - val_sparse_categorical_accuracy: 0.7510 - learning_rate: 1.0000e-04
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.3687 - sparse_categorical_accuracy: 0.8783 - val_loss: 0.5961 - val_sparse_categorical_accuracy: 0.8103 - learning_rate: 1.0000e-04
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.3220 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.5752 - val_sparse_categorical_accuracy: 0.8340 - learning_rate: 1.0000e-04
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.2822 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.5835 - val_sparse_categorical_accuracy: 0.8419 - learning_rate: 1.0000e-04
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.2535 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.5778 - val_sparse_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.5507 - val_sparse_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.2129 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.6382 - val_sparse_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - loss: 0.1944 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.5492 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - loss: 0.1781 - sparse_categorical_accuracy: 0.9421 - val_loss: 0.4931 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1587 - sparse_categorical_accuracy: 0.9500 - val_loss: 0.5296 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1287 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.6122 - val_sparse_categorical_accuracy: 0.8419 - learning_rate: 1.0000e-04
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1387 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.5378 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.4765 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1033 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.6146 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.7717 - val_sparse_categorical_accuracy: 0.8300 - learning_rate: 1.0000e-04
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.7785 - val_sparse_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.6999 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 1.0000e-04
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.7039 - val_sparse_categorical_accuracy: 0.8577 - learning_rate: 1.0000e-04
# Epoch 39/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9748
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.6314 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 40/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0649 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.5643 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 5.0000e-05
# Epoch 41/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0642 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.4722 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 42/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0577 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.4683 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 5.0000e-05
# Epoch 43/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.4730 - val_sparse_categorical_accuracy: 0.9249 - learning_rate: 5.0000e-05
# Epoch 44/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.4759 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 5.0000e-05
# Epoch 45/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0477 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.4837 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 5.0000e-05
# Epoch 46/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0453 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.4819 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 47/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.4661 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 48/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.4902 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 49/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.5245 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 50/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.5452 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 51/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.5359 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 5.0000e-05
# Epoch 52/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.5255 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 53/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0428 - sparse_categorical_accuracy: 0.9892
# Epoch 53: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.5034 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 5.0000e-05
# Epoch 54/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.4823 - val_sparse_categorical_accuracy: 0.9249 - learning_rate: 2.5000e-05
# Epoch 55/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.4739 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 56/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.4705 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 57/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.4537 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 58/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.4500 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 2.5000e-05
# Epoch 59/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0250 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4578 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 60/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.4633 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 61/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.4562 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 62/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.4559 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 63/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.4461 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 64/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.4286 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 65/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4160 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 66/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4115 - val_sparse_categorical_accuracy: 0.9289 - learning_rate: 2.5000e-05
# Epoch 67/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.4159 - val_sparse_categorical_accuracy: 0.9289 - learning_rate: 2.5000e-05
# Epoch 68/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.4177 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 2.5000e-05
# Epoch 69/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.4208 - val_sparse_categorical_accuracy: 0.9249 - learning_rate: 2.5000e-05
# Epoch 70/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4247 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 2.5000e-05
# Epoch 71/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4230 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 2.5000e-05
# Epoch 72/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9921
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.4234 - val_sparse_categorical_accuracy: 0.9289 - learning_rate: 2.5000e-05
# Epoch 73/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.4241 - val_sparse_categorical_accuracy: 0.9289 - learning_rate: 1.2500e-05
# Epoch 74/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4280 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 1.2500e-05
# Epoch 75/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4290 - val_sparse_categorical_accuracy: 0.9249 - learning_rate: 1.2500e-05
# Epoch 76/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.4310 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.2500e-05
# Epoch 77/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4276 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.2500e-05
# Epoch 78/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0215 - sparse_categorical_accuracy: 0.9934
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.4248 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.2500e-05
# Epoch 79/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.4247 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 6.2500e-06
# Epoch 80/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - loss: 0.0212 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.4273 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 6.2500e-06
# Epoch 81/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4295 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 6.2500e-06
# Epoch 82/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0183 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.4313 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 6.2500e-06
# Epoch 83/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.4343 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 6.2500e-06
# Epoch 84/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9932
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4344 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 6.2500e-06
# Epoch 85/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4342 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 3.1250e-06
# Epoch 86/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4338 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 3.1250e-06
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 66.

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9960
# [0.012184706516563892, 0.9960415363311768]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 0.4115 - sparse_categorical_accuracy: 0.9289
# [0.4115283787250519, 0.9288537502288818]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.4601 - sparse_categorical_accuracy: 0.9051
# [0.4600957930088043, 0.9051383137702942]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       1.00      1.00      1.00       322
#        glass       1.00      0.99      0.99       401
#        metal       0.98      1.00      0.99       328
#        paper       1.00      1.00      1.00       475
#      plastic       1.00      0.99      1.00       385
#        trash       1.00      0.99      1.00       110
#
#     accuracy                           1.00      2021
#    macro avg       1.00      1.00      1.00      2021
# weighted avg       1.00      1.00      1.00      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.95      0.95      0.95        40
#        glass       0.93      0.86      0.90        50
#        metal       0.85      0.98      0.91        41
#        paper       0.97      1.00      0.98        60
#      plastic       0.91      0.90      0.91        48
#        trash       1.00      0.79      0.88        14
#
#     accuracy                           0.93       253
#    macro avg       0.94      0.91      0.92       253
# weighted avg       0.93      0.93      0.93       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.89      0.95      0.92        41
#        glass       0.98      0.86      0.91        50
#        metal       0.76      0.93      0.84        41
#        paper       0.93      0.95      0.94        59
#      plastic       1.00      0.88      0.93        49
#        trash       0.83      0.77      0.80        13
#
#     accuracy                           0.91       253
#    macro avg       0.90      0.89      0.89       253
# weighted avg       0.91      0.91      0.91       253
