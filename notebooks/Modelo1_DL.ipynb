# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# c:\Users\juanw\Desktop\garbage-classification

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os

# %%
import random
import tensorflow as tf
import os

# Establecer semilla para reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1134  data/Garbage-classification/Garbage-classifica...    metal
# 2487  data/Garbage-classification/Garbage-classifica...    trash
# 2228  data/Garbage-classification/Garbage-classifica...  plastic
# 2346  data/Garbage-classification/Garbage-classifica...  plastic
# 2048  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print(f"📦 Dataset descargado en: {path}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     143 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:93, in DatasetApiClient.download_dataset(self, request)
#      91   request = ApiDownloadDatasetRequest()
# ---> 93 return self._client.call("datasets.DatasetApiService", "DownloadDataset", request, HttpRedirect)
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglesdk\kaggle_http_client.py:98, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      96 http_response = self._session.send(http_request, **settings)
# ---> 98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglesdk\kaggle_http_client.py:124, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     123     pass
# --> 124 http_response.raise_for_status()
#     125 # Allow client to check header content.
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.kaggle.com/v1/datasets.DatasetApiService/DownloadDataset
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[6], line 4
#       1 import kagglehub
#       3 # Descargar dataset
# ----> 4 path = kagglehub.dataset_download("asdasdasasdas/garbage-classification", path="data/")
#       6 print(f"📦 Dataset descargado en: {path}")
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)
#      21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)
#      33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve(self, h, path, force_download, output_dir)
#     141 if path:
#     142     # Downloading a single file.
#     143     os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144     response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145     download_file(response, out_path, h, extract_auto_compressed_file=True)
#     146 else:
#     147     # TODO(b/345800027) Implement parallel download when < 25 files in databundle.
#     148     # Downloading the full archived bundle.
#
# File c:\Users\juanw\Desktop\garbage-classification\venv\Lib\site-packages\kagglehub\exceptions.py:107, in handle_call(fn, resource_handle)
#      98     message = (
#      99         f"{e.response.status_code} Client Error."
#     100         "\n\n"
#    (...)
#     103         "Please make sure you specified the correct resource identifiers."
#     104     )
#     106 # Default handling
# --> 107 raise KaggleApiHTTPError(message, response=e.response) from e
#
# KaggleApiHTTPError: 404 Client Error.
#
# Resource not found at URL: https://api.kaggle.com/datasets/asdasdasasdas/garbage-classification/versions/2
# Please make sure you specified the correct resource identifiers.

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual) 

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []
    
    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']
        
        img = cv2.imread(ruta)                  
        img = cv2.resize(img, (size, size))    
        img = img.astype('float32') / 255.0    
        
        images.append(img)
        labels.append(label)
    
    X = np.array(images)
    y = np.array(labels)
    
    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from src.modelo1 import estructura_modelo
from src.modelo_simple import compilar
from src.curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo,resumen=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_))
print(resumen)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │       393,222 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 412,614 (1.57 MB)
#  Trainable params: 412,614 (1.57 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
modelo=compilar(modelo,learning_rate=0.001)

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=128,epochs=100)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9965 - val_loss: 2.5575 - val_sparse_categorical_accuracy: 0.6087
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9970 - val_loss: 2.5763 - val_sparse_categorical_accuracy: 0.6047
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9975 - val_loss: 2.6503 - val_sparse_categorical_accuracy: 0.5771
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9960 - val_loss: 2.6940 - val_sparse_categorical_accuracy: 0.6008
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9955 - val_loss: 2.6605 - val_sparse_categorical_accuracy: 0.6047
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s
100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 12s 785ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9980 - val_loss: 4.1405 - val_sparse_categorical_accuracy: 0.5850

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9990
# [0.0025322369765490294, 0.9990103840827942]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5664 - sparse_categorical_accuracy: 0.5217
# [2.5663650035858154, 0.52173912525177]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3547 - sparse_categorical_accuracy: 0.5968
# [2.3546738624572754, 0.5968379378318787]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       1.00      1.00      1.00       322
#        glass       1.00      1.00      1.00       401
#        metal       1.00      1.00      1.00       328
#        paper       1.00      1.00      1.00       475
#      plastic       1.00      1.00      1.00       385
#        trash       1.00      1.00      1.00       110
#
#     accuracy                           1.00      2021
#    macro avg       1.00      1.00      1.00      2021
# weighted avg       1.00      1.00      1.00      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.78      0.78      0.78        40
#        glass       0.58      0.44      0.50        50
#        metal       0.36      0.32      0.34        41
#        paper       0.57      0.60      0.59        60
#      plastic       0.42      0.56      0.48        48
#        trash       0.27      0.21      0.24        14
#
#     accuracy                           0.52       253
#    macro avg       0.50      0.48      0.49       253
# weighted avg       0.52      0.52      0.52       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.78      0.76      0.77        41
#        glass       0.63      0.34      0.44        50
#        metal       0.61      0.46      0.53        41
#        paper       0.62      0.69      0.66        59
#      plastic       0.49      0.76      0.59        49
#        trash       0.46      0.46      0.46        13
#
#     accuracy                           0.60       253
#    macro avg       0.60      0.58      0.57       253
# weighted avg       0.61      0.60      0.59       253
