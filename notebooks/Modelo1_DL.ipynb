# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# c:\Users\juanw\Desktop\garbage-classification

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1398  data/Garbage-classification/Garbage-classifica...    paper
# 680   data/Garbage-classification/Garbage-classifica...    glass
# 1423  data/Garbage-classification/Garbage-classifica...    paper
# 1650  data/Garbage-classification/Garbage-classifica...    paper
# 2129  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification", path="data/")

print(f"📦 Dataset descargado en: {path}")

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual) 

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []
    
    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']
        
        img = cv2.imread(ruta)                  
        img = cv2.resize(img, (size, size))    
        img = img.astype('float32') / 255.0    
        
        images.append(img)
        labels.append(label)
    
    X = np.array(images)
    y = np.array(labels)
    
    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from src.modelo1 import estructura_modelo
from src.modelo_simple import compilar
from src.curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo,resumen=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_))
print(resumen)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,094 (4.27 KB)
#  Trainable params: 1,094 (4.27 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
modelo=compilar(modelo,learning_rate=0.01)

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=128,epochs=200)
# Out:
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 1.7413 - sparse_categorical_accuracy: 0.2128 - val_loss: 1.7209 - val_sparse_categorical_accuracy: 0.1976
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 1.7190 - sparse_categorical_accuracy: 0.2177 - val_loss: 1.7064 - val_sparse_categorical_accuracy: 0.2372
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 1.7067 - sparse_categorical_accuracy: 0.2197 - val_loss: 1.6908 - val_sparse_categorical_accuracy: 0.2569
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - loss: 1.6887 - sparse_categorical_accuracy: 0.2474 - val_loss: 1.6596 - val_sparse_categorical_accuracy: 0.3004
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 1.6663 - sparse_categorical_accuracy: 0.2909 - val_loss: 1.6220 - val_sparse_categorical_accuracy: 0.3913
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - loss: 1.6389 - sparse_categorical_accuracy: 0.3107 - val_loss: 1.5933 - val_sparse_categorical_accuracy: 0.3123
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 1.6166 - sparse_categorical_accuracy: 0.3310 - val_loss: 1.5655 - val_sparse_categorical_accuracy: 0.3597
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 1.5777 - sparse_categorical_accuracy: 0.3805 - val_loss: 1.5396 - val_sparse_categorical_accuracy: 0.3597
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - loss: 1.5634 - sparse_categorical_accuracy: 0.3894 - val_loss: 1.5137 - val_sparse_categorical_accuracy: 0.3597
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 250ms/step - loss: 1.5473 - sparse_categorical_accuracy: 0.3637 - val_loss: 1.4992 - val_sparse_categorical_accuracy: 0.3992
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - loss: 1.5426 - sparse_categorical_accuracy: 0.4008 - val_loss: 1.4966 - val_sparse_categorical_accuracy: 0.3834
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - loss: 1.5355 - sparse_categorical_accuracy: 0.3958 - val_loss: 1.4761 - val_sparse_categorical_accuracy: 0.3834
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 1.5326 - sparse_categorical_accuracy: 0.3924 - val_loss: 1.4652 - val_sparse_categorical_accuracy: 0.4111
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 1.5442 - sparse_categorical_accuracy: 0.3775 - val_loss: 1.4918 - val_sparse_categorical_accuracy: 0.3834
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.5215 - sparse_categorical_accuracy: 0.3874 - val_loss: 1.5077 - val_sparse_categorical_accuracy: 0.3992
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - loss: 1.5412 - sparse_categorical_accuracy: 0.3899 - val_loss: 1.4747 - val_sparse_categorical_accuracy: 0.3794
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - loss: 1.5167 - sparse_categorical_accuracy: 0.3889 - val_loss: 1.4532 - val_sparse_categorical_accuracy: 0.4308
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 1.5183 - sparse_categorical_accuracy: 0.3919 - val_loss: 1.4593 - val_sparse_categorical_accuracy: 0.4032
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - loss: 1.5110 - sparse_categorical_accuracy: 0.3756 - val_loss: 1.4421 - val_sparse_categorical_accuracy: 0.4032
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 1.5038 - sparse_categorical_accuracy: 0.3953 - val_loss: 1.4800 - val_sparse_categorical_accuracy: 0.3913
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - loss: 1.5069 - sparse_categorical_accuracy: 0.3929 - val_loss: 1.4396 - val_sparse_categorical_accuracy: 0.4150
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.5029 - sparse_categorical_accuracy: 0.3968 - val_loss: 1.4358 - val_sparse_categorical_accuracy: 0.4190
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - loss: 1.5033 - sparse_categorical_accuracy: 0.3889 - val_loss: 1.4346 - val_sparse_categorical_accuracy: 0.3715
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 1.4989 - sparse_categorical_accuracy: 0.3963 - val_loss: 1.4268 - val_sparse_categorical_accuracy: 0.3834
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.4967 - sparse_categorical_accuracy: 0.3998 - val_loss: 1.4266 - val_sparse_categorical_accuracy: 0.4229
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 1.4854 - sparse_categorical_accuracy: 0.3988 - val_loss: 1.4224 - val_sparse_categorical_accuracy: 0.3755
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 1.4875 - sparse_categorical_accuracy: 0.3899 - val_loss: 1.4152 - val_sparse_categorical_accuracy: 0.4427
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 1.4855 - sparse_categorical_accuracy: 0.4028 - val_loss: 1.4259 - val_sparse_categorical_accuracy: 0.3755
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 1.4847 - sparse_categorical_accuracy: 0.3780 - val_loss: 1.4162 - val_sparse_categorical_accuracy: 0.4150
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 1.4842 - sparse_categorical_accuracy: 0.3973 - val_loss: 1.4363 - val_sparse_categorical_accuracy: 0.3953
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.4851 - sparse_categorical_accuracy: 0.4087 - val_loss: 1.4148 - val_sparse_categorical_accuracy: 0.3874
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.4861 - sparse_categorical_accuracy: 0.3899 - val_loss: 1.4113 - val_sparse_categorical_accuracy: 0.3992
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.4787 - sparse_categorical_accuracy: 0.4018 - val_loss: 1.4036 - val_sparse_categorical_accuracy: 0.3834
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.4884 - sparse_categorical_accuracy: 0.3993 - val_loss: 1.4144 - val_sparse_categorical_accuracy: 0.4466
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.4769 - sparse_categorical_accuracy: 0.3968 - val_loss: 1.4271 - val_sparse_categorical_accuracy: 0.4229
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.4706 - sparse_categorical_accuracy: 0.4038 - val_loss: 1.4079 - val_sparse_categorical_accuracy: 0.4466
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.4641 - sparse_categorical_accuracy: 0.4008 - val_loss: 1.4055 - val_sparse_categorical_accuracy: 0.4190
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 1.4656 - sparse_categorical_accuracy: 0.4023 - val_loss: 1.4025 - val_sparse_categorical_accuracy: 0.4150
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1
200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.3548 - sparse_categorical_accuracy: 0.4384 - val_loss: 1.2814 - val_sparse_categorical_accuracy: 0.4585
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.3429 - sparse_categorical_accuracy: 0.4587 - val_loss: 1.2960 - val_sparse_categorical_accuracy: 0.4664
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.3410 - sparse_categorical_accuracy: 0.4532 - val_loss: 1.2822 - val_sparse_categorical_accuracy: 0.4862
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 1.3474 - sparse_categorical_accuracy: 0.4577 - val_loss: 1.2857 - val_sparse_categorical_accuracy: 0.4545
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.3466 - sparse_categorical_accuracy: 0.4592 - val_loss: 1.2940 - val_sparse_categorical_accuracy: 0.4506
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.3533 - sparse_categorical_accuracy: 0.4602 - val_loss: 1.2982 - val_sparse_categorical_accuracy: 0.4664
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 1.3478 - sparse_categorical_accuracy: 0.4587 - val_loss: 1.2818 - val_sparse_categorical_accuracy: 0.4743
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.3381 - sparse_categorical_accuracy: 0.4617 - val_loss: 1.2641 - val_sparse_categorical_accuracy: 0.4822
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - loss: 1.3337 - sparse_categorical_accuracy: 0.4676 - val_loss: 1.2787 - val_sparse_categorical_accuracy: 0.4743
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.3413 - sparse_categorical_accuracy: 0.4523 - val_loss: 1.3227 - val_sparse_categorical_accuracy: 0.4783
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 1.3579 - sparse_categorical_accuracy: 0.4587 - val_loss: 1.2879 - val_sparse_categorical_accuracy: 0.4862
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 1.3413 - sparse_categorical_accuracy: 0.4612 - val_loss: 1.2674 - val_sparse_categorical_accuracy: 0.4664
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 1.3330 - sparse_categorical_accuracy: 0.4626 - val_loss: 1.2970 - val_sparse_categorical_accuracy: 0.4743
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 1.3299 - sparse_categorical_accuracy: 0.4671 - val_loss: 1.2676 - val_sparse_categorical_accuracy: 0.4625
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 1.3184 - sparse_categorical_accuracy: 0.4725 - val_loss: 1.2849 - val_sparse_categorical_accuracy: 0.4466
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.3211 - sparse_categorical_accuracy: 0.4770 - val_loss: 1.2771 - val_sparse_categorical_accuracy: 0.4545
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 1.3262 - sparse_categorical_accuracy: 0.4725 - val_loss: 1.2742 - val_sparse_categorical_accuracy: 0.4664
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 1.3330 - sparse_categorical_accuracy: 0.4597 - val_loss: 1.2894 - val_sparse_categorical_accuracy: 0.5020
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.3424 - sparse_categorical_accuracy: 0.4790 - val_loss: 1.2582 - val_sparse_categorical_accuracy: 0.4941
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.3095 - sparse_categorical_accuracy: 0.4805 - val_loss: 1.2724 - val_sparse_categorical_accuracy: 0.4743
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 1.3150 - sparse_categorical_accuracy: 0.4780 - val_loss: 1.2631 - val_sparse_categorical_accuracy: 0.5296
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 1.3178 - sparse_categorical_accuracy: 0.4696 - val_loss: 1.2610 - val_sparse_categorical_accuracy: 0.5020
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 1.3228 - sparse_categorical_accuracy: 0.4770 - val_loss: 1.2692 - val_sparse_categorical_accuracy: 0.4585
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 1.2998 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.2478 - val_sparse_categorical_accuracy: 0.5375
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.3034 - sparse_categorical_accuracy: 0.4790 - val_loss: 1.2584 - val_sparse_categorical_accuracy: 0.4427
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.2921 - sparse_categorical_accuracy: 0.4750 - val_loss: 1.2318 - val_sparse_categorical_accuracy: 0.5217
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.3026 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.2512 - val_sparse_categorical_accuracy: 0.4980
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 1.3111 - sparse_categorical_accuracy: 0.4859 - val_loss: 1.2759 - val_sparse_categorical_accuracy: 0.4862
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 1.3073 - sparse_categorical_accuracy: 0.4790 - val_loss: 1.2484 - val_sparse_categorical_accuracy: 0.4901
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 1.2821 - sparse_categorical_accuracy: 0.4874 - val_loss: 1.2308 - val_sparse_categorical_accuracy: 0.4783
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 1.2906 - sparse_categorical_accuracy: 0.4824 - val_loss: 1.2228 - val_sparse_categorical_accuracy: 0.5099
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.2922 - sparse_categorical_accuracy: 0.4819 - val_loss: 1.2185 - val_sparse_categorical_accuracy: 0.5099
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.2930 - sparse_categorical_accuracy: 0.4775 - val_loss: 1.2274 - val_sparse_categorical_accuracy: 0.4862
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 1.2835 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.2303 - val_sparse_categorical_accuracy: 0.5217
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.2825 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.2464 - val_sparse_categorical_accuracy: 0.4704
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - loss: 1.2805 - sparse_categorical_accuracy: 0.4814 - val_loss: 1.2279 - val_sparse_categorical_accuracy: 0.5257
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.2840 - sparse_categorical_accuracy: 0.4874 - val_loss: 1.2080 - val_sparse_categorical_accuracy: 0.4980
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 1.2692 - sparse_categorical_accuracy: 0.4859 - val_loss: 1.2182 - val_sparse_categorical_accuracy: 0.4783
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 1.2668 - sparse_categorical_accuracy: 0.4933 - val_loss: 1.2000 - val_sparse_categorical_accuracy: 0.5138
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 1.2786 - sparse_categorical_accuracy: 0.4839 - val_loss: 1.2102 - val_sparse_categorical_accuracy: 0.4901
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 1.2736 - sparse_categorical_accuracy: 0.4814 - val_loss: 1.2155 - val_sparse_categorical_accuracy: 0.5375
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 1.2776 - sparse_categorical_accuracy: 0.4938 - val_loss: 1.2371 - val_sparse_categorical_accuracy: 0.4743
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 1.2613 - sparse_categorical_accuracy: 0.4874 - val_loss: 1.2072 - val_sparse_categorical_accuracy: 0.5059
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 1.2652 - sparse_categorical_accuracy: 0.4810 - val_loss: 1.2126 - val_sparse_categorical_accuracy: 0.5415
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 1.2593 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.1969 - val_sparse_categorical_accuracy: 0.4980
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 1.2707 - sparse_categorical_accuracy: 0.4824 - val_loss: 1.1941 - val_sparse_categorical_accuracy: 0.4941
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 1.2561 - sparse_categorical_accuracy: 0.4918 - val_loss: 1.2023 - val_sparse_categorical_accuracy: 0.5059
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.2632 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.1991 - val_sparse_categorical_accuracy: 0.4783
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step
- sparse_categorical_accuracy: 0.4973 - val_loss: 1.1774 - val_sparse_categorical_accuracy: 0.4901
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 1.2474 - sparse_categorical_accuracy: 0.4918 - val_loss: 1.1966 - val_sparse_categorical_accuracy: 0.4901
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 1.2563 - sparse_categorical_accuracy: 0.4958 - val_loss: 1.2055 - val_sparse_categorical_accuracy: 0.4783
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - loss: 1.2394 - sparse_categorical_accuracy: 0.4938 - val_loss: 1.1820 - val_sparse_categorical_accuracy: 0.5178
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - loss: 1.2399 - sparse_categorical_accuracy: 0.4963 - val_loss: 1.1911 - val_sparse_categorical_accuracy: 0.5020
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - loss: 1.2288 - sparse_categorical_accuracy: 0.5052 - val_loss: 1.1881 - val_sparse_categorical_accuracy: 0.5020
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - loss: 1.2297 - sparse_categorical_accuracy: 0.5077 - val_loss: 1.1731 - val_sparse_categorical_accuracy: 0.5217
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 1.2321 - sparse_categorical_accuracy: 0.4918 - val_loss: 1.1774 - val_sparse_categorical_accuracy: 0.5020
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 1.2342 - sparse_categorical_accuracy: 0.4998 - val_loss: 1.1768 - val_sparse_categorical_accuracy: 0.5178
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.2280 - sparse_categorical_accuracy: 0.5017 - val_loss: 1.1810 - val_sparse_categorical_accuracy: 0.5099
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 1.2341 - sparse_categorical_accuracy: 0.5166 - val_loss: 1.1784 - val_sparse_categorical_accuracy: 0.5336
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.2343 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.1678 - val_sparse_categorical_accuracy: 0.5178
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 1.2323 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.1770 - val_sparse_categorical_accuracy: 0.5099
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 1.2290 - sparse_categorical_accuracy: 0.4918 - val_loss: 1.1610 - val_sparse_categorical_accuracy: 0.5217
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 1.2343 - sparse_categorical_accuracy: 0.4948 - val_loss: 1.1724 - val_sparse_categorical_accuracy: 0.5217
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 1.2335 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.1862 - val_sparse_categorical_accuracy: 0.5296
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 1.2334 - sparse_categorical_accuracy: 0.4968 - val_loss: 1.1839 - val_sparse_categorical_accuracy: 0.4901
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.2256 - sparse_categorical_accuracy: 0.5002 - val_loss: 1.1813 - val_sparse_categorical_accuracy: 0.5217
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.2211 - sparse_categorical_accuracy: 0.5087 - val_loss: 1.1658 - val_sparse_categorical_accuracy: 0.5059
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 1.2239 - sparse_categorical_accuracy: 0.4943 - val_loss: 1.1898 - val_sparse_categorical_accuracy: 0.4980
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.2198 - sparse_categorical_accuracy: 0.4973 - val_loss: 1.1657 - val_sparse_categorical_accuracy: 0.5375
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 1.2226 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.1922 - val_sparse_categorical_accuracy: 0.5099
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - loss: 1.2243 - sparse_categorical_accuracy: 0.5027 - val_loss: 1.1766 - val_sparse_categorical_accuracy: 0.5415
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.2226 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.1704 - val_sparse_categorical_accuracy: 0.5257
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 1.2285 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.1683 - val_sparse_categorical_accuracy: 0.4901
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.2212 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.1640 - val_sparse_categorical_accuracy: 0.5336
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - loss: 1.2375 - sparse_categorical_accuracy: 0.5092 - val_loss: 1.1823 - val_sparse_categorical_accuracy: 0.4822
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 1.2247 - sparse_categorical_accuracy: 0.5096 - val_loss: 1.1703 - val_sparse_categorical_accuracy: 0.5455
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 1.2243 - sparse_categorical_accuracy: 0.5062 - val_loss: 1.1568 - val_sparse_categorical_accuracy: 0.5415
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 1.2291 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.1807 - val_sparse_categorical_accuracy: 0.5217
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 1.2198 - sparse_categorical_accuracy: 0.5082 - val_loss: 1.1660 - val_sparse_categorical_accuracy: 0.5415
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 1.2187 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.1610 - val_sparse_categorical_accuracy: 0.5178
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 1.2156 - sparse_categorical_accuracy: 0.5106 - val_loss: 1.1646 - val_sparse_categorical_accuracy: 0.5494
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 1.2140 - sparse_categorical_accuracy: 0.5037 - val_loss: 1.1865 - val_sparse_categorical_accuracy: 0.5178
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 1.2193 - sparse_categorical_accuracy: 0.5087 - val_loss: 1.1609 - val_sparse_categorical_accuracy: 0.5494
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 1.2179 - sparse_categorical_accuracy: 0.5087 - val_loss: 1.1619 - val_sparse_categorical_accuracy: 0.5415
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.2159 - sparse_categorical_accuracy: 0.5092 - val_loss: 1.1771 - val_sparse_categorical_accuracy: 0.5257
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 1.2277 - sparse_categorical_accuracy: 0.5146 - val_loss: 1.1682 - val_sparse_categorical_accuracy: 0.5178
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 1.2107 - sparse_categorical_accuracy: 0.5121 - val_loss: 1.1710 - val_sparse_categorical_accuracy: 0.5336
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 1.2164 - sparse_categorical_accuracy: 0.5205 - val_loss: 1.1837 - val_sparse_categorical_accuracy: 0.5099
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 1.2152 - sparse_categorical_accuracy: 0.5087 - val_loss: 1.1723 - val_sparse_categorical_accuracy: 0.5099
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 1.2110 - sparse_categorical_accuracy: 0.5141 - val_loss: 1.1731 - val_sparse_categorical_accuracy: 0.5020
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 1.2152 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.1746 - val_sparse_categorical_accuracy: 0.5336
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 1.2191 - sparse_categorical_accuracy: 0.5037 - val_loss: 1.1619 - val_sparse_categorical_accuracy: 0.5296
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 1.2137 - sparse_categorical_accuracy: 0.5131 - val_loss: 1.1665 - val_sparse_categorical_accuracy: 0.5375
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 1.2162 - sparse_categorical_accuracy: 0.5106 - val_loss: 1.1729 - val_sparse_categorical_accuracy: 0.5099
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 1.2341 - sparse_categorical_accuracy: 0.5106 - val_loss: 1.2183 - val_sparse_categorical_accuracy: 0.5020
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 1.2229 - sparse_categorical_accuracy: 0.5077 - val_loss: 1.1997 - val_sparse_categorical_accuracy: 0.5178
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 1.2381 - sparse_categorical_accuracy: 0.5126 - val_loss: 1.1860 - val_sparse_categorical_accuracy: 0.4743

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3649 - sparse_categorical_accuracy: 0.4631
# [1.36493718624115, 0.46313706040382385]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3103 - sparse_categorical_accuracy: 0.4506
# [1.3102786540985107, 0.45059287548065186]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3958 - sparse_categorical_accuracy: 0.4545
# [1.3958364725112915, 0.4545454680919647]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       0.64      0.71      0.68       322
#        glass       0.40      0.26      0.31       401
#        metal       0.42      0.26      0.32       328
#        paper       0.42      0.57      0.49       475
#      plastic       0.44      0.64      0.52       385
#        trash       0.00      0.00      0.00       110
#
#     accuracy                           0.46      2021
#    macro avg       0.39      0.41      0.39      2021
# weighted avg       0.43      0.46      0.44      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.76      0.70      0.73        40
#        glass       0.37      0.28      0.32        50
#        metal       0.48      0.24      0.32        41
#        paper       0.36      0.45      0.40        60
#      plastic       0.43      0.73      0.54        48
#        trash       0.00      0.00      0.00        14
#
#     accuracy                           0.45       253
#    macro avg       0.40      0.40      0.38       253
# weighted avg       0.44      0.45      0.43       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.72      0.76      0.74        41
#        glass       0.52      0.32      0.40        50
#        metal       0.42      0.24      0.31        41
#        paper       0.40      0.51      0.45        59
#      plastic       0.35      0.57      0.43        49
#        trash       0.00      0.00      0.00        13
#
#     accuracy                           0.45       253
#    macro avg       0.40      0.40      0.39       253
# weighted avg       0.45      0.45      0.44       253
