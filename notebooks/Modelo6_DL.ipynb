# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# /

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
import random
import tensorflow as tf
import os

# Establecer semilla para reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1134  data/Garbage-classification/Garbage-classifica...    metal
# 2487  data/Garbage-classification/Garbage-classifica...    trash
# 2228  data/Garbage-classification/Garbage-classifica...  plastic
# 2346  data/Garbage-classification/Garbage-classifica...  plastic
# 2048  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print(f"📦 Dataset descargado en: {path}")
# Out:
# Using Colab cache for faster access to the 'garbage-classification' dataset.
# 📦 Dataset descargado en: /kaggle/input/garbage-classification

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual)

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []

    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']

        img = cv2.imread(ruta)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (size, size))
        #img = img.astype('float32') / 255.0

        images.append(img)
        labels.append(label)

    X = np.array(images)
    y = np.array(labels)

    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
#Para usar resnet50
x_train = preprocess_input(x_train.astype("float32"))
x_val = preprocess_input(x_val.astype("float32"))
x_test = preprocess_input(x_test.astype("float32"))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from src.modelo6 import estructura_modelo
from src.modelo_simple import compilar
from src.curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_))
modelo
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 4, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,147,078 (92.11 MB)
#  Trainable params: 24,093,190 (91.91 MB)
#  Non-trainable params: 53,888 (210.50 KB)
# <Sequential name=sequential_2, built=True>

# %%
modelo=compilar(modelo,learning_rate=1e-4)

# %%
ReduceLROnPlateau=tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1
    )

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=256,epochs=200,callbacks=ReduceLROnPlateau)
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - loss: 1.8506 - sparse_categorical_accuracy: 0.2994 - val_loss: 1.4342 - val_sparse_categorical_accuracy: 0.5217 - learning_rate: 1.0000e-04
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 852ms/step - loss: 1.0876 - sparse_categorical_accuracy: 0.5888 - val_loss: 1.1174 - val_sparse_categorical_accuracy: 0.6166 - learning_rate: 1.0000e-04
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 895ms/step - loss: 0.7691 - sparse_categorical_accuracy: 0.7650 - val_loss: 1.0123 - val_sparse_categorical_accuracy: 0.6640 - learning_rate: 1.0000e-04
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 916ms/step - loss: 0.5786 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.9153 - val_sparse_categorical_accuracy: 0.7154 - learning_rate: 1.0000e-04
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 932ms/step - loss: 0.4273 - sparse_categorical_accuracy: 0.9030 - val_loss: 0.8033 - val_sparse_categorical_accuracy: 0.7470 - learning_rate: 1.0000e-04
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 908ms/step - loss: 0.3272 - sparse_categorical_accuracy: 0.9377 - val_loss: 0.6992 - val_sparse_categorical_accuracy: 0.7549 - learning_rate: 1.0000e-04
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.2526 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.6159 - val_sparse_categorical_accuracy: 0.7747 - learning_rate: 1.0000e-04
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.1969 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.5601 - val_sparse_categorical_accuracy: 0.7905 - learning_rate: 1.0000e-04
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.5109 - val_sparse_categorical_accuracy: 0.8182 - learning_rate: 1.0000e-04
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step - loss: 0.1399 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.4696 - val_sparse_categorical_accuracy: 0.8379 - learning_rate: 1.0000e-04
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 850ms/step - loss: 0.1123 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.4329 - val_sparse_categorical_accuracy: 0.8458 - learning_rate: 1.0000e-04
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 846ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.4070 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 1.0000e-04
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 854ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3910 - val_sparse_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 859ms/step - loss: 0.0767 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.3671 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 1.0000e-04
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-04
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 888ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 886ms/step - loss: 0.0536 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-04
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 883ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.3194 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 1.0000e-04
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.3112 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.0421 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3092 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0401 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3050 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 856ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3012 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 1.0000e-04
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2938 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 1.0000e-04
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 853ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2889 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.0000e-04
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.2889 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 1.0000e-04
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2848 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.0000e-04
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2836 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-04
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 911ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2883 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 1.0000e-04
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2874 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-04
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0249 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2863 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-04
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2901 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-04
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2975 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.0000e-04
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9991
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.2960 - val_sparse_categorical_accuracy: 0.9249 - learning_rate: 1.0000e-04
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2945 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 5.0000e-05
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 919ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.2980 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3051 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0197 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3098 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 860ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - loss: 0.0198 - sparse_categorical_accuracy: 0.9999
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3154 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0186 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3174 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 2.5000e-05
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0196 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3201 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 2.5000e-05
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.0190 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3210 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 2.5000e-05
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.3208 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 2.5000e-05
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 878ms/step - loss: 0.0188 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3221 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 2.5000e-05
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - loss: 0.0179 - sparse_categorical_accuracy: 1.0000
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0188 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 2.5000e-05
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3240 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.2500e-05
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0174 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3248 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.2500e-05
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.2500e-05
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3269 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.2500e-05
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0176 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3288 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.2500e-05
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - loss: 0.0175 - sparse_categorical_accuracy: 1.0000
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3288 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.2500e-05
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 912ms/step - loss: 0.0182 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3291 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 6.2500e-06
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3300 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 6.2500e-06
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3307 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 6.2500e-06
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 861ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3315 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 6.2500e-06
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3324 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 6.2500e-06
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9998
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 882ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 6.2500e-06
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3339 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 3.1250e-06
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 885ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 3.1250e-06
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 3.1250e-06
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 3.1250e-06
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 909ms/step - loss: 0.0197 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3368 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 3.1250e-06
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.0181 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 3.1250e-06
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3385 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3389 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3396 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - loss: 0.0179 - sparse_categorical_accuracy: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0177 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3400 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.5625e-06
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 883ms/step - loss: 0.0179 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3405 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 876ms/step - loss: 0.0179 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3412 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0175 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0174 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3419 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3421 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 917ms/step - loss: 0.0156 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3430 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.0175 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3436 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 861ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3440 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3442 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 921ms/step - loss: 0.0157 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3442 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0174 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3442 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 876ms/step - loss: 0.0182 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3442 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 859ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 854ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3442 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0160 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 882ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3446 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 894ms/step - loss: 0.0180 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3448 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 883ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3448 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 853ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3450 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.0161 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3452 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 852ms/step - loss: 0.0159 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3453 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3453 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 879ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 872ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0157 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 854ms/step - loss: 0.0160 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3457 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0164 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-06
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0157 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 0.0154 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0171 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3462 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0173 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3461 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3462 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0164 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0159 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0154 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 878ms/step - loss: 0.0153 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 877ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3472 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 0.0153 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 863ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0150 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 861ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 882ms/step - loss: 0.0184 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 876ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 866ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3472 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0153 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3472 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0160 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3472 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0165 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3471 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3472 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0166 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0150 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3468 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0156 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3470 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0172 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3474 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3474 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3475 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 865ms/step - loss: 0.0168 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3475 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0178 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3483 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0159 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3486 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0170 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3485 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3486 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 0.0156 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 0.0164 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 876ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 921ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3485 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 0.0146 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3485 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0151 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0160 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 861ms/step - loss: 0.0145 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 911ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 855ms/step - loss: 0.0147 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 863ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 860ms/step - loss: 0.0155 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3492 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - loss: 0.0153 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0169 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 857ms/step - loss: 0.0159 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3486 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 919ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 858ms/step - loss: 0.0152 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 870ms/step - loss: 0.0154 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3491 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 862ms/step - loss: 0.0150 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 875ms/step - loss: 0.0162 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3496 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 0.0156 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3497 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 869ms/step - loss: 0.0158 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3499 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 876ms/step - loss: 0.0163 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3502 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0164 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 871ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.3505 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 868ms/step - loss: 0.0154 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.3507 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-06

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9990
# [0.005801446735858917, 0.9990103840827942]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.3507 - sparse_categorical_accuracy: 0.8933
# [0.3507315218448639, 0.8932806253433228]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4339 - sparse_categorical_accuracy: 0.8735
# [0.43387266993522644, 0.8735178112983704]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       1.00      1.00      1.00       322
#        glass       1.00      1.00      1.00       401
#        metal       1.00      1.00      1.00       328
#        paper       1.00      1.00      1.00       475
#      plastic       1.00      1.00      1.00       385
#        trash       1.00      1.00      1.00       110
#
#     accuracy                           1.00      2021
#    macro avg       1.00      1.00      1.00      2021
# weighted avg       1.00      1.00      1.00      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.78      0.78      0.78        40
#        glass       0.58      0.44      0.50        50
#        metal       0.36      0.32      0.34        41
#        paper       0.57      0.60      0.59        60
#      plastic       0.42      0.56      0.48        48
#        trash       0.27      0.21      0.24        14
#
#     accuracy                           0.52       253
#    macro avg       0.50      0.48      0.49       253
# weighted avg       0.52      0.52      0.52       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.78      0.76      0.77        41
#        glass       0.63      0.34      0.44        50
#        metal       0.61      0.46      0.53        41
#        paper       0.62      0.69      0.66        59
#      plastic       0.49      0.76      0.59        49
#        trash       0.46      0.46      0.46        13
#
#     accuracy                           0.60       253
#    macro avg       0.60      0.58      0.57       253
# weighted avg       0.61      0.60      0.59       253
