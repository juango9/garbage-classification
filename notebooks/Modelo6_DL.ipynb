# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# /

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
import random
import tensorflow as tf
import os

# Establecer semilla para reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1134  data/Garbage-classification/Garbage-classifica...    metal
# 2487  data/Garbage-classification/Garbage-classifica...    trash
# 2228  data/Garbage-classification/Garbage-classifica...  plastic
# 2346  data/Garbage-classification/Garbage-classifica...  plastic
# 2048  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print(f"📦 Dataset descargado en: {path}")
# Out:
# Using Colab cache for faster access to the 'garbage-classification' dataset.
# 📦 Dataset descargado en: /kaggle/input/garbage-classification

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual)

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []

    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']

        img = cv2.imread(ruta)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (size, size))
        #img = img.astype('float32') / 255.0

        images.append(img)
        labels.append(label)

    X = np.array(images)
    y = np.array(labels)

    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
#Para usar resnet50
x_train = preprocess_input(x_train.astype("float32"))
x_val = preprocess_input(x_val.astype("float32"))
x_test = preprocess_input(x_test.astype("float32"))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from src.modelo6 import estructura_modelo
from src.modelo_simple import compilar
from src.curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_))
modelo
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 4, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,161,926 (92.17 MB)
#  Trainable params: 24,108,806 (91.97 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# <Sequential name=sequential_2, built=True>

# %%
modelo=compilar(modelo,learning_rate=1e-4)

# %%
ReduceLROnPlateau=tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1
    )

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=256,epochs=80,callbacks=ReduceLROnPlateau)
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 90s 5s/step - loss: 2.1249 - sparse_categorical_accuracy: 0.2078 - val_loss: 1.4426 - val_sparse_categorical_accuracy: 0.4545 - learning_rate: 1.0000e-04
# Epoch 2/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 697ms/step - loss: 1.6200 - sparse_categorical_accuracy: 0.3350 - val_loss: 1.2266 - val_sparse_categorical_accuracy: 0.5217 - learning_rate: 1.0000e-04
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 706ms/step - loss: 1.3539 - sparse_categorical_accuracy: 0.4646 - val_loss: 1.1042 - val_sparse_categorical_accuracy: 0.5534 - learning_rate: 1.0000e-04
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 703ms/step - loss: 1.1767 - sparse_categorical_accuracy: 0.5398 - val_loss: 1.0000 - val_sparse_categorical_accuracy: 0.6206 - learning_rate: 1.0000e-04
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - loss: 1.0000 - sparse_categorical_accuracy: 0.6155 - val_loss: 0.9108 - val_sparse_categorical_accuracy: 0.6482 - learning_rate: 1.0000e-04
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - loss: 0.8531 - sparse_categorical_accuracy: 0.6719 - val_loss: 0.8653 - val_sparse_categorical_accuracy: 0.6719 - learning_rate: 1.0000e-04
# Epoch 7/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 720ms/step - loss: 0.7164 - sparse_categorical_accuracy: 0.7234 - val_loss: 0.8526 - val_sparse_categorical_accuracy: 0.6957 - learning_rate: 1.0000e-04
# Epoch 8/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 720ms/step - loss: 0.6003 - sparse_categorical_accuracy: 0.7763 - val_loss: 0.8071 - val_sparse_categorical_accuracy: 0.7431 - learning_rate: 1.0000e-04
# Epoch 9/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 718ms/step - loss: 0.5044 - sparse_categorical_accuracy: 0.8154 - val_loss: 0.7563 - val_sparse_categorical_accuracy: 0.7747 - learning_rate: 1.0000e-04
# Epoch 10/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 730ms/step - loss: 0.4186 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.7110 - val_sparse_categorical_accuracy: 0.7984 - learning_rate: 1.0000e-04
# Epoch 11/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 728ms/step - loss: 0.3371 - sparse_categorical_accuracy: 0.8798 - val_loss: 0.6878 - val_sparse_categorical_accuracy: 0.8261 - learning_rate: 1.0000e-04
# Epoch 12/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 735ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.6670 - val_sparse_categorical_accuracy: 0.8340 - learning_rate: 1.0000e-04
# Epoch 13/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 737ms/step - loss: 0.2093 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.6511 - val_sparse_categorical_accuracy: 0.8340 - learning_rate: 1.0000e-04
# Epoch 14/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 744ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.5798 - val_sparse_categorical_accuracy: 0.8577 - learning_rate: 1.0000e-04
# Epoch 15/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 743ms/step - loss: 0.1407 - sparse_categorical_accuracy: 0.9570 - val_loss: 0.5309 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 16/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 754ms/step - loss: 0.1287 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.5033 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 17/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 749ms/step - loss: 0.0955 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.4437 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 18/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 758ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.4236 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 1.0000e-04
# Epoch 19/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 759ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.4138 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 1.0000e-04
# Epoch 20/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 760ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 1.0000e-04
# Epoch 21/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 759ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.4275 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 1.0000e-04
# Epoch 22/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 768ms/step - loss: 0.0495 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.4710 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 23/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 766ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.4992 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 24/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 772ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.4799 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 1.0000e-04
# Epoch 25/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 772ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.4532 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 26/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9891
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 771ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.4541 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 1.0000e-04
# Epoch 27/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 761ms/step - loss: 0.0240 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.4527 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 28/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 768ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.4460 - val_sparse_categorical_accuracy: 0.8972 - learning_rate: 5.0000e-05
# Epoch 29/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 762ms/step - loss: 0.0360 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.4248 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 5.0000e-05
# Epoch 30/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 773ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4090 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 31/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 772ms/step - loss: 0.0227 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3980 - val_sparse_categorical_accuracy: 0.9012 - learning_rate: 5.0000e-05
# Epoch 32/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 776ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.3903 - val_sparse_categorical_accuracy: 0.9051 - learning_rate: 5.0000e-05
# Epoch 33/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 775ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9926 - val_loss: 0.3758 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 34/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 780ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.3822 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 35/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 776ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3881 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 36/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 780ms/step - loss: 0.0261 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3948 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 37/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 776ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.4073 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 38/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 785ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.4323 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 5.0000e-05
# Epoch 39/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9968
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 779ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.4397 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 5.0000e-05
# Epoch 40/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 781ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.4373 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 2.5000e-05
# Epoch 41/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 781ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.4302 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 2.5000e-05
# Epoch 42/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 780ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4234 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 2.5000e-05
# Epoch 43/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 781ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.4178 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 2.5000e-05
# Epoch 44/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 788ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.4098 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 2.5000e-05
# Epoch 45/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9939
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 782ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.4065 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 2.5000e-05
# Epoch 46/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 786ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.4044 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.2500e-05
# Epoch 47/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 785ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.4009 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 1.2500e-05
# Epoch 48/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 792ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3992 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.2500e-05
# Epoch 49/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 782ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3986 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.2500e-05
# Epoch 50/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 790ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3989 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.2500e-05
# Epoch 51/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9950
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 782ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.3984 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.2500e-05
# Epoch 52/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 792ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.3983 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 6.2500e-06
# Epoch 53/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 783ms/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3977 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 6.2500e-06
# Epoch 54/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 788ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3976 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 6.2500e-06
# Epoch 55/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 787ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3971 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 6.2500e-06
# Epoch 56/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 793ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3956 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 6.2500e-06
# Epoch 57/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9915
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 788ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3951 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 6.2500e-06
# Epoch 58/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 791ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.3946 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 3.1250e-06
# Epoch 59/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 794ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.3944 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 3.1250e-06
# Epoch 60/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 792ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3941 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 3.1250e-06
# Epoch 61/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 794ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.3940 - val_sparse_categorical_accuracy: 0.9091 - learning_rate: 3.1250e-06
# Epoch 62/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 790ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.3945 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 3.1250e-06
# Epoch 63/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9985
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 795ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3950 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 3.1250e-06
# Epoch 64/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 796ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3949 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 65/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 797ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.3946 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 66/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 789ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 67/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 800ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.3942 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 68/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 791ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 69/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9948
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 798ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3940 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.5625e-06
# Epoch 70/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 788ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.3935 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 71/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 793ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3930 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 72/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 789ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3927 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 73/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 794ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 74/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 790ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.3924 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 75/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 796ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 76/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 791ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.3926 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 77/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 800ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3924 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.0000e-06
# Epoch 78/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 793ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 1.0000e-06
# Epoch 79/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 800ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.3917 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06
# Epoch 80/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 793ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.3914 - val_sparse_categorical_accuracy: 0.9170 - learning_rate: 1.0000e-06

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9990
# [0.0017506752628833055, 0.9990103840827942]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 0.3914 - sparse_categorical_accuracy: 0.9170
# [0.39144450426101685, 0.9169960618019104]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6331 - sparse_categorical_accuracy: 0.8893
# [0.6330954432487488, 0.8893280625343323]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       1.00      1.00      1.00       322
#        glass       1.00      1.00      1.00       401
#        metal       1.00      1.00      1.00       328
#        paper       1.00      1.00      1.00       475
#      plastic       1.00      1.00      1.00       385
#        trash       1.00      1.00      1.00       110
#
#     accuracy                           1.00      2021
#    macro avg       1.00      1.00      1.00      2021
# weighted avg       1.00      1.00      1.00      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.97      0.97      0.97        40
#        glass       0.83      0.86      0.84        50
#        metal       0.93      0.90      0.91        41
#        paper       0.97      0.97      0.97        60
#      plastic       0.90      0.90      0.90        48
#        trash       0.92      0.86      0.89        14
#
#     accuracy                           0.92       253
#    macro avg       0.92      0.91      0.91       253
# weighted avg       0.92      0.92      0.92       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.97      0.95      0.96        41
#        glass       0.91      0.86      0.89        50
#        metal       0.89      0.83      0.86        41
#        paper       0.89      0.95      0.92        59
#      plastic       0.83      0.92      0.87        49
#        trash       0.73      0.62      0.67        13
#
#     accuracy                           0.89       253
#    macro avg       0.87      0.85      0.86       253
# weighted avg       0.89      0.89      0.89       253
