# %% [markdown]
# # Modelo 1

# %%
# %cd ..
# Out:
# /

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,accuracy_score
import os
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
import random
import tensorflow as tf
import os

# Establecer semilla para reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## Carga de Datos

# %%
from src.carga import cargar_datos

# %%
root = 'data/Garbage-classification/Garbage-classification/'
df = cargar_datos(root)
df.head()
# Out:
#                                                       x        y
# 1134  data/Garbage-classification/Garbage-classifica...    metal
# 2487  data/Garbage-classification/Garbage-classifica...    trash
# 2228  data/Garbage-classification/Garbage-classifica...  plastic
# 2346  data/Garbage-classification/Garbage-classifica...  plastic
# 2048  data/Garbage-classification/Garbage-classifica...  plastic

# %% [markdown]
# ## Carga de datos en Colab

# %%
import kagglehub

# Descargar dataset
path = kagglehub.dataset_download("asdasdasasdas/garbage-classification")

print(f"📦 Dataset descargado en: {path}")
# Out:
# Using Colab cache for faster access to the 'garbage-classification' dataset.
# 📦 Dataset descargado en: /kaggle/input/garbage-classification

# %%
import pandas as pd
import os

def cargar_datos_colab(ruta_archivo):
    data = {}

    for i in os.listdir(ruta_archivo):
      if i == 'Garbage classification':
        ruta_clase = os.path.join(ruta_archivo,i)
        if os.path.isdir(ruta_clase):
            for ruta_actual, subcarpetas, archivos in os.walk(ruta_clase):
                for k in archivos:
                    data[os.path.join(ruta_actual, k)] = os.path.basename(ruta_actual)

    df = pd.DataFrame(data.items(), columns=['x', 'y'])
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    return df

# %%
df = cargar_datos_colab(path)

# %% [markdown]
# ## Division de los datos

# %%
from sklearn.model_selection import train_test_split

# 80% train, 20% (test + validación)
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['y']
 )

# Del 20% (test + validacion): 10% validación y 10% test
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    stratify=temp_df['y']
 )

print(f"Train: {len(train_df)} ({len(train_df)/len(df):.1%})")
print(f"Validación: {len(val_df)} ({len(val_df)/len(df):.1%})")
print(f"Test: {len(test_df)} ({len(test_df)/len(df):.1%})")
# Out:
# Train: 2021 (80.0%)
# Validación: 253 (10.0%)
# Test: 253 (10.0%)

# %% [markdown]
# ## Modificacion de las imagenes y carga en memoria.

# %%
def load_images(df, size):
    images = []
    labels = []

    for _, row in df.iterrows():
        ruta = row['x']
        label = row['y']

        img = cv2.imread(ruta)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (size, size))
        #img = img.astype('float32') / 255.0

        images.append(img)
        labels.append(label)

    X = np.array(images)
    y = np.array(labels)

    return X, y

# %%
x_train, y_train = load_images(train_df, size=128)
x_val, y_val = load_images(val_df, size=128)
x_test, y_test = load_images(test_df, size=128)

# %%
#Para usar resnet50
x_train = preprocess_input(x_train.astype("float32"))
x_val = preprocess_input(x_val.astype("float32"))
x_test = preprocess_input(x_test.astype("float32"))

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((2021, 128, 128, 3),
#  (2021,),
#  (253, 128, 128, 3),
#  (253,),
#  (253, 128, 128, 3),
#  (253,))

# %% [markdown]
# Encoder para los labels

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_val  = le.transform(y_val)
y_test  = le.transform(y_test)

# %%
le.classes_
# Out:
# array(['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash'],
#       dtype='<U9')

# %% [markdown]
# ## Aplicacion del modelo

# %%
from modelo7 import estructura_modelo
from modelo_simple import compilar
from curvas import graf_pedida,graf_acc,plot_confusion

# %%
modelo=estructura_modelo(input_shape=(128, 128, 3), num_classes=len(le.classes_))
modelo
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 4, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,147,078 (92.11 MB)
#  Trainable params: 558,598 (2.13 MB)
#  Non-trainable params: 23,588,480 (89.98 MB)
# <Sequential name=sequential, built=True>

# %%
modelo=compilar(modelo,learning_rate=1e-4)

# %%
ReduceLROnPlateau=tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=6,
        min_lr=1e-6,
        verbose=1
    )

# %%
hist = modelo.fit(x_train,y_train,validation_data=(x_val, y_val),batch_size=256,epochs=200,callbacks=ReduceLROnPlateau)
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 2.2383 - sparse_categorical_accuracy: 0.2207 - val_loss: 1.7641 - val_sparse_categorical_accuracy: 0.2411 - learning_rate: 1.0000e-04
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - loss: 1.8515 - sparse_categorical_accuracy: 0.3152 - val_loss: 1.3946 - val_sparse_categorical_accuracy: 0.4466 - learning_rate: 1.0000e-04
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 1.5884 - sparse_categorical_accuracy: 0.4003 - val_loss: 1.1769 - val_sparse_categorical_accuracy: 0.5573 - learning_rate: 1.0000e-04
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 1.3789 - sparse_categorical_accuracy: 0.4775 - val_loss: 1.0439 - val_sparse_categorical_accuracy: 0.6245 - learning_rate: 1.0000e-04
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - loss: 1.2513 - sparse_categorical_accuracy: 0.5235 - val_loss: 0.9559 - val_sparse_categorical_accuracy: 0.6719 - learning_rate: 1.0000e-04
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - loss: 1.1003 - sparse_categorical_accuracy: 0.6012 - val_loss: 0.8926 - val_sparse_categorical_accuracy: 0.6917 - learning_rate: 1.0000e-04
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - loss: 1.0368 - sparse_categorical_accuracy: 0.6200 - val_loss: 0.8418 - val_sparse_categorical_accuracy: 0.7036 - learning_rate: 1.0000e-04
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - loss: 0.9708 - sparse_categorical_accuracy: 0.6428 - val_loss: 0.8011 - val_sparse_categorical_accuracy: 0.7352 - learning_rate: 1.0000e-04
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - loss: 0.9098 - sparse_categorical_accuracy: 0.6616 - val_loss: 0.7623 - val_sparse_categorical_accuracy: 0.7470 - learning_rate: 1.0000e-04
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - loss: 0.8616 - sparse_categorical_accuracy: 0.6962 - val_loss: 0.7297 - val_sparse_categorical_accuracy: 0.7708 - learning_rate: 1.0000e-04
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.7214 - val_loss: 0.7035 - val_sparse_categorical_accuracy: 0.7826 - learning_rate: 1.0000e-04
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - loss: 0.7634 - sparse_categorical_accuracy: 0.7442 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.7826 - learning_rate: 1.0000e-04
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - loss: 0.7547 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.6530 - val_sparse_categorical_accuracy: 0.7945 - learning_rate: 1.0000e-04
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - loss: 0.7165 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.6304 - val_sparse_categorical_accuracy: 0.8024 - learning_rate: 1.0000e-04
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - loss: 0.6943 - sparse_categorical_accuracy: 0.7669 - val_loss: 0.6099 - val_sparse_categorical_accuracy: 0.8063 - learning_rate: 1.0000e-04
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - loss: 0.6705 - sparse_categorical_accuracy: 0.7669 - val_loss: 0.5911 - val_sparse_categorical_accuracy: 0.8142 - learning_rate: 1.0000e-04
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - loss: 0.6279 - sparse_categorical_accuracy: 0.7932 - val_loss: 0.5749 - val_sparse_categorical_accuracy: 0.8142 - learning_rate: 1.0000e-04
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - loss: 0.6228 - sparse_categorical_accuracy: 0.7853 - val_loss: 0.5614 - val_sparse_categorical_accuracy: 0.8221 - learning_rate: 1.0000e-04
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.5814 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.5495 - val_sparse_categorical_accuracy: 0.8221 - learning_rate: 1.0000e-04
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - loss: 0.5758 - sparse_categorical_accuracy: 0.8100 - val_loss: 0.5388 - val_sparse_categorical_accuracy: 0.8261 - learning_rate: 1.0000e-04
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 0.5555 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.5287 - val_sparse_categorical_accuracy: 0.8261 - learning_rate: 1.0000e-04
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - loss: 0.5311 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.5193 - val_sparse_categorical_accuracy: 0.8261 - learning_rate: 1.0000e-04
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - loss: 0.5403 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.5121 - val_sparse_categorical_accuracy: 0.8300 - learning_rate: 1.0000e-04
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 241ms/step - loss: 0.5085 - sparse_categorical_accuracy: 0.8402 - val_loss: 0.5050 - val_sparse_categorical_accuracy: 0.8340 - learning_rate: 1.0000e-04
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.4983 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.4963 - val_sparse_categorical_accuracy: 0.8340 - learning_rate: 1.0000e-04
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.4731 - sparse_categorical_accuracy: 0.8431 - val_loss: 0.4877 - val_sparse_categorical_accuracy: 0.8379 - learning_rate: 1.0000e-04
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - loss: 0.4509 - sparse_categorical_accuracy: 0.8595 - val_loss: 0.4802 - val_sparse_categorical_accuracy: 0.8379 - learning_rate: 1.0000e-04
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 0.4591 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.4730 - val_sparse_categorical_accuracy: 0.8419 - learning_rate: 1.0000e-04
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step - loss: 0.4393 - sparse_categorical_accuracy: 0.8575 - val_loss: 0.4669 - val_sparse_categorical_accuracy: 0.8419 - learning_rate: 1.0000e-04
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - loss: 0.4355 - sparse_categorical_accuracy: 0.8619 - val_loss: 0.4620 - val_sparse_categorical_accuracy: 0.8458 - learning_rate: 1.0000e-04
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.4164 - sparse_categorical_accuracy: 0.8728 - val_loss: 0.4579 - val_sparse_categorical_accuracy: 0.8458 - learning_rate: 1.0000e-04
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.4013 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.4534 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 1.0000e-04
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 0.3980 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.4493 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 1.0000e-04
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - loss: 0.3772 - sparse_categorical_accuracy: 0.8946 - val_loss: 0.4459 - val_sparse_categorical_accuracy: 0.8458 - learning_rate: 1.0000e-04
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step - loss: 0.3771 - sparse_categorical_accuracy: 0.8862 - val_loss: 0.4416 - val_sparse_categorical_accuracy: 0.8458 - learning_rate: 1.0000e-04
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - loss: 0.3779 - sparse_categorical_accuracy: 0.8857 - val_loss: 0.4365 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 1.0000e-04
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.3668 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.4312 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - loss: 0.3463 - sparse_categorical_accuracy: 0.8916 - val_loss: 0.4273 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.3375 - sparse_categorical_accuracy: 0.8971 - val_loss: 0.4236 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.3238 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.4192 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.3214 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.4165 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 239ms/step - loss: 0.3133 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.4136 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.3147 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.4105 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.2990 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.4082 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 239ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.4060 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.2809 - sparse_categorical_accuracy: 0.9278 - val_loss: 0.4025 - val_sparse_categorical_accuracy: 0.8617 - learning_rate: 1.0000e-04
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - loss: 0.2704 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.3989 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.2696 - sparse_categorical_accuracy: 0.9273 - val_loss: 0.3957 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 239ms/step - loss: 0.2588 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.3946 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.2567 - sparse_categorical_accuracy: 0.9342 - val_loss: 0.3938 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - loss: 0.2503 - sparse_categorical_accuracy: 0.9327 - val_loss: 0.3910 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.2394 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.3879 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.2467 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.2435 - sparse_categorical_accuracy: 0.9342 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - loss: 0.2194 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.3800 - val_sparse_categorical_accuracy: 0.8656 - learning_rate: 1.0000e-04
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.2260 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.3775 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.2273 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.3746 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.2149 - sparse_categorical_accuracy: 0.9471 - val_loss: 0.3723 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - loss: 0.2081 - sparse_categorical_accuracy: 0.9530 - val_loss: 0.3714 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - loss: 0.2056 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.3702 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - loss: 0.2023 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.3700 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - loss: 0.2003 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.3676 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.1908 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.3657 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - loss: 0.1853 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.3641 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - loss: 0.1702 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - loss: 0.1688 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3632 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.3621 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.1739 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.3609 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step - loss: 0.1608 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.3602 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.3599 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1540 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.3582 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1533 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.3576 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.1449 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.3563 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.3548 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1507 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.3538 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.1309 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.1374 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.3464 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 1.0000e-04
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.3450 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.1296 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.3452 - val_sparse_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - loss: 0.1188 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.3454 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.1254 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.3456 - val_sparse_categorical_accuracy: 0.8775 - learning_rate: 1.0000e-04
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.1195 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.3435 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.1256 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.3414 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.3403 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.1148 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - loss: 0.1099 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3400 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.0963 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-04
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.3428 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0977 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 1.0000e-04
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9822
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 1.0000e-04
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.3432 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0911 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3411 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3401 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 5.0000e-05
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0935 - sparse_categorical_accuracy: 0.9890
# Epoch 100: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 5.0000e-05
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0917 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 2.5000e-05
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3385 - val_sparse_categorical_accuracy: 0.8893 - learning_rate: 2.5000e-05
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 2.5000e-05
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - loss: 0.0988 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.3385 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 2.5000e-05
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 2.5000e-05
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9863
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0883 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3384 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 2.5000e-05
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0821 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0851 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3375 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3369 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.0877 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0868 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3363 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3365 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0901 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0877 - sparse_categorical_accuracy: 0.9887
# Epoch 120: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0896 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.2500e-05
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.0836 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3365 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3363 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0848 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3359 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3355 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0810 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3355 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3355 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3353 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8814 - learning_rate: 6.2500e-06
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0920 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0814 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0806 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0819 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - loss: 0.0814 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9828
# Epoch 147: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0838 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 6.2500e-06
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0777 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0815 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0913 - sparse_categorical_accuracy: 0.9896
# Epoch 153: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0848 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 3.1250e-06
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - loss: 0.0894 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9906
# Epoch 159: ReduceLROnPlateau reducing learning rate to 1e-06.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0810 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.5625e-06
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - loss: 0.0794 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0846 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0759 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0857 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0809 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0767 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0813 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0849 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0892 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0809 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 269ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0846 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 0.0775 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0851 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step - loss: 0.0858 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - loss: 0.0823 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0866 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0801 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0802 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0811 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - loss: 0.0813 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.0811 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step - loss: 0.0803 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8854 - learning_rate: 1.0000e-06

# %%
grafico = graf_pedida(hist)
print(grafico)
# Out:
# None

# %%
grafico2 = graf_acc(hist)
print(grafico2)
# Out:
# None

# %% [markdown]
# ### Evaluamos el modelo

# %%
score1 = modelo.evaluate(x_train, y_train, steps=100)
print(score1)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9985
# [0.026817090809345245, 0.9985156059265137]

# %%
score2 = modelo.evaluate(x_val, y_val, steps=100)
print(score2)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.8854
# [0.33481931686401367, 0.8853754997253418]

# %%
score3 = modelo.evaluate(x_test, y_test, steps=100)
print(score3)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4181 - sparse_categorical_accuracy: 0.8656
# [0.4181074798107147, 0.8656126260757446]

# %% [markdown]
# ### Matrices de confusion

# %%
y_train_pred = modelo.predict(x_train)
y_train_pred = y_train_pred.argmax(axis=1)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step

# %%
y_val_pred = modelo.predict(x_val)
y_val_pred = y_val_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 467ms/step

# %%
y_test_pred = modelo.predict(x_test)
y_test_pred = y_test_pred.argmax(axis=1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
plot_confusion(y_train, y_train_pred, le.classes_, title='Matriz de confusion (entrenamiento)')

# %%
plot_confusion(y_val, y_val_pred, le.classes_, title='Matriz de confusion (validacion)')

# %%
plot_confusion(y_test, y_test_pred, le.classes_, title='Matriz de confusion (test)')

# %% [markdown]
# ### Más metricas

# %%
print("Classification Report - Train:")
print(classification_report(y_train, y_train_pred, target_names=le.classes_))
# Out:
# Classification Report - Train:
#               precision    recall  f1-score   support
#
#    cardboard       1.00      1.00      1.00       322
#        glass       1.00      1.00      1.00       401
#        metal       1.00      1.00      1.00       328
#        paper       1.00      1.00      1.00       475
#      plastic       1.00      1.00      1.00       385
#        trash       1.00      1.00      1.00       110
#
#     accuracy                           1.00      2021
#    macro avg       1.00      1.00      1.00      2021
# weighted avg       1.00      1.00      1.00      2021

# %%
print("Classification Report - validacion:")
print(classification_report(y_val, y_val_pred, target_names=le.classes_))
# Out:
# Classification Report - validacion:
#               precision    recall  f1-score   support
#
#    cardboard       0.95      0.95      0.95        40
#        glass       0.81      0.88      0.85        50
#        metal       0.82      0.90      0.86        41
#        paper       0.95      0.95      0.95        60
#      plastic       0.89      0.83      0.86        48
#        trash       0.89      0.57      0.70        14
#
#     accuracy                           0.89       253
#    macro avg       0.89      0.85      0.86       253
# weighted avg       0.89      0.89      0.88       253

# %%
print("Classification Report - test:")
print(classification_report(y_test, y_test_pred, target_names=le.classes_))
# Out:
# Classification Report - test:
#               precision    recall  f1-score   support
#
#    cardboard       0.95      0.95      0.95        41
#        glass       0.91      0.86      0.89        50
#        metal       0.80      0.90      0.85        41
#        paper       0.85      0.90      0.88        59
#      plastic       0.87      0.80      0.83        49
#        trash       0.67      0.62      0.64        13
#
#     accuracy                           0.87       253
#    macro avg       0.84      0.84      0.84       253
# weighted avg       0.87      0.87      0.87       253
